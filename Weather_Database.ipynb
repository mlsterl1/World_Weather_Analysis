# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
import timeit
import random

# Import the API key.
from config import g_key

# %%
gmaps.configure(api_key=g_key)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e141afc1224931002e974913d4c84ba9

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# List of city data
city_data = []# Print to logger
# print("Beginning Data Retrieval     ")
# print("-----------------------------")# Create counters
record_count = 1
set_count = 1# Loop through all the cities in our list
for i, city in enumerate(cities):    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")    # Add 1 to the record count
    record_count += 1    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        pass        
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        pass           
        # Append the City information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches})
    # If an error is experienced, skip the city    
    except:
        print("City not found. Skipping...")
        pass

    
# print("-----------------------------")
# print("Data Retrieval Complete      ")
#print("-----------------------------")
# Convert the array of dictionaries to a Pandas DataFrame.
# Out:
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | moranbah
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | fort nelson
# Processing Record 5 of Set 1 | katsuura
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | necochea
# Processing Record 10 of Set 1 | barra do garcas
# Processing Record 11 of Set 1 | puri
# Processing Record 12 of Set 1 | key west
# Processing Record 13 of Set 1 | khipro
# Processing Record 14 of Set 1 | grafton
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | warrnambool
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | marfino
# Processing Record 22 of Set 1 | samarai
# Processing Record 23 of Set 1 | coquimbo
# Processing Record 24 of Set 1 | west wendover
# Processing Record 25 of Set 1 | taoudenni
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | evensk
# Processing Record 31 of Set 1 | arak
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | hurghada
# Processing Record 36 of Set 1 | xichang
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | vila franca do campo
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | gorontalo
# Processing Record 41 of Set 1 | kautokeino
# Processing Record 42 of Set 1 | nuuk
# Processing Record 43 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 1 | paracuru
# Processing Record 45 of Set 1 | tabou
# Processing Record 46 of Set 1 | dingle
# Processing Record 47 of Set 1 | teya
# Processing Record 48 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | faya
# Processing Record 1 of Set 2 | nidzica
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | bad krozingen
# Processing Record 4 of Set 2 | khatanga
# Processing Record 5 of Set 2 | norman wells
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | talawdi
# City not found. Skipping...
# Processing Record 8 of Set 2 | oistins
# Processing Record 9 of Set 2 | lufilufi
# Processing Record 10 of Set 2 | dubrovytsya
# Processing Record 11 of Set 2 | parrita
# Processing Record 12 of Set 2 | sochi
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | klaksvik
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | vostok
# Processing Record 18 of Set 2 | airai
# Processing Record 19 of Set 2 | grande-riviere
# City not found. Skipping...
# Processing Record 20 of Set 2 | stara pazova
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | leshukonskoye
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | urengoy
# Processing Record 28 of Set 2 | sao felix do xingu
# Processing Record 29 of Set 2 | pacific grove
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | kavieng
# Processing Record 32 of Set 2 | jiaojiang
# Processing Record 33 of Set 2 | igarka
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | santo antonio do ica
# Processing Record 36 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | college
# Processing Record 39 of Set 2 | saint george
# Processing Record 40 of Set 2 | port blair
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | bathsheba
# Processing Record 44 of Set 2 | berlevag
# Processing Record 45 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 2 | fortuna
# Processing Record 47 of Set 2 | labuhan
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | shubarshi
# Processing Record 1 of Set 3 | bumbuna
# Processing Record 2 of Set 3 | rocha
# Processing Record 3 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 4 of Set 3 | presidencia roque saenz pena
# Processing Record 5 of Set 3 | taksimo
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | hobart
# Processing Record 8 of Set 3 | zhuji
# Processing Record 9 of Set 3 | shache
# Processing Record 10 of Set 3 | bredasdorp
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | lasa
# Processing Record 13 of Set 3 | talnakh
# Processing Record 14 of Set 3 | tawnat
# City not found. Skipping...
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | ancud
# Processing Record 17 of Set 3 | nanortalik
# Processing Record 18 of Set 3 | kindu
# Processing Record 19 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | am timan
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | kizukuri
# Processing Record 24 of Set 3 | gambela
# Processing Record 25 of Set 3 | half moon bay
# Processing Record 26 of Set 3 | dosso
# Processing Record 27 of Set 3 | kristiinankaupunki
# Processing Record 28 of Set 3 | lavrentiya
# Processing Record 29 of Set 3 | high level
# Processing Record 30 of Set 3 | guane
# Processing Record 31 of Set 3 | hovd
# Processing Record 32 of Set 3 | gunzenhausen
# Processing Record 33 of Set 3 | hamilton
# Processing Record 34 of Set 3 | faanui
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | hasaki
# Processing Record 37 of Set 3 | ardesen
# Processing Record 38 of Set 3 | miyako
# Processing Record 39 of Set 3 | mossendjo
# Processing Record 40 of Set 3 | russkaya polyana
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 43 of Set 3 | karratha
# Processing Record 44 of Set 3 | jalu
# Processing Record 45 of Set 3 | sassandra
# Processing Record 46 of Set 3 | ziarat
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | deputatskiy
# Processing Record 49 of Set 3 | yamada
# Processing Record 50 of Set 3 | porto novo
# Processing Record 1 of Set 4 | eureka
# Processing Record 2 of Set 4 | bambous virieux
# Processing Record 3 of Set 4 | isangel
# Processing Record 4 of Set 4 | ahuimanu
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | marsh harbour
# Processing Record 7 of Set 4 | carauari
# Processing Record 8 of Set 4 | blagoyevo
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | sysert
# Processing Record 11 of Set 4 | chishtian mandi
# Processing Record 12 of Set 4 | stepnogorsk
# Processing Record 13 of Set 4 | tessalit
# Processing Record 14 of Set 4 | qena
# Processing Record 15 of Set 4 | tual
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | naze
# Processing Record 18 of Set 4 | saint-louis
# Processing Record 19 of Set 4 | fort smith
# Processing Record 20 of Set 4 | avarua
# Processing Record 21 of Set 4 | kargasok
# Processing Record 22 of Set 4 | ixtapa
# Processing Record 23 of Set 4 | ayan
# Processing Record 24 of Set 4 | los llanos de aridane
# Processing Record 25 of Set 4 | ginir
# Processing Record 26 of Set 4 | mount pleasant
# Processing Record 27 of Set 4 | sampit
# Processing Record 28 of Set 4 | puerto cabezas
# Processing Record 29 of Set 4 | kasongo-lunda
# Processing Record 30 of Set 4 | saint-pierre
# Processing Record 31 of Set 4 | georgetown
# Processing Record 32 of Set 4 | la ronge
# Processing Record 33 of Set 4 | knysna
# Processing Record 34 of Set 4 | saint-francois
# Processing Record 35 of Set 4 | umm lajj
# Processing Record 36 of Set 4 | zhob
# Processing Record 37 of Set 4 | husavik
# Processing Record 38 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 4 | hualmay
# Processing Record 40 of Set 4 | villaviciosa
# Processing Record 41 of Set 4 | pisco
# Processing Record 42 of Set 4 | mehamn
# Processing Record 43 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 4 | kahului
# Processing Record 45 of Set 4 | svetlogorsk
# Processing Record 46 of Set 4 | biak
# Processing Record 47 of Set 4 | puerto colombia
# Processing Record 48 of Set 4 | grindavik
# Processing Record 49 of Set 4 | margate
# Processing Record 50 of Set 4 | ejido
# Processing Record 1 of Set 5 | sidney
# Processing Record 2 of Set 5 | dinard
# Processing Record 3 of Set 5 | kokoda
# Processing Record 4 of Set 5 | dikson
# Processing Record 5 of Set 5 | sarakhs
# Processing Record 6 of Set 5 | salalah
# Processing Record 7 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | roald
# Processing Record 10 of Set 5 | forbach
# Processing Record 11 of Set 5 | north platte
# Processing Record 12 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 5 | sabha
# Processing Record 14 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 5 | pipar
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | christchurch
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | spirit river
# Processing Record 20 of Set 5 | mwene-ditu
# Processing Record 21 of Set 5 | carutapera
# Processing Record 22 of Set 5 | mount gambier
# Processing Record 23 of Set 5 | moorhead
# Processing Record 24 of Set 5 | bengkulu
# Processing Record 25 of Set 5 | chokurdakh
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | tigil
# Processing Record 28 of Set 5 | east london
# Processing Record 29 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 5 | buchanan
# Processing Record 31 of Set 5 | borba
# Processing Record 32 of Set 5 | acapulco
# Processing Record 33 of Set 5 | thompson
# Processing Record 34 of Set 5 | clyde river
# Processing Record 35 of Set 5 | erdenet
# Processing Record 36 of Set 5 | nanzhang
# Processing Record 37 of Set 5 | jumla
# Processing Record 38 of Set 5 | setermoen
# Processing Record 39 of Set 5 | souillac
# Processing Record 40 of Set 5 | kaitangata
# Processing Record 41 of Set 5 | kondoa
# Processing Record 42 of Set 5 | turbat
# Processing Record 43 of Set 5 | coahuayana
# Processing Record 44 of Set 5 | the valley
# Processing Record 45 of Set 5 | wolsztyn
# Processing Record 46 of Set 5 | bocana de paiwas
# Processing Record 47 of Set 5 | santa marinella
# Processing Record 48 of Set 5 | pangnirtung
# Processing Record 49 of Set 5 | dan khun thot
# Processing Record 50 of Set 5 | sokoni
# Processing Record 1 of Set 6 | tilichiki
# Processing Record 2 of Set 6 | egvekinot
# Processing Record 3 of Set 6 | sao filipe
# Processing Record 4 of Set 6 | bafra
# Processing Record 5 of Set 6 | bousse
# Processing Record 6 of Set 6 | constitucion
# Processing Record 7 of Set 6 | shahr-e babak
# Processing Record 8 of Set 6 | tura
# Processing Record 9 of Set 6 | abadiania
# Processing Record 10 of Set 6 | iskateley
# Processing Record 11 of Set 6 | nador
# Processing Record 12 of Set 6 | narrabri
# Processing Record 13 of Set 6 | acarau
# Processing Record 14 of Set 6 | buin
# Processing Record 15 of Set 6 | bethel
# Processing Record 16 of Set 6 | yuncheng
# Processing Record 17 of Set 6 | kenai
# Processing Record 18 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 6 | torbay
# Processing Record 20 of Set 6 | lompoc
# Processing Record 21 of Set 6 | payao
# Processing Record 22 of Set 6 | kiunga
# Processing Record 23 of Set 6 | stokmarknes
# Processing Record 24 of Set 6 | inhambane
# Processing Record 25 of Set 6 | shimoda
# Processing Record 26 of Set 6 | kapoeta
# Processing Record 27 of Set 6 | camacha
# Processing Record 28 of Set 6 | hirado
# Processing Record 29 of Set 6 | chinsali
# Processing Record 30 of Set 6 | bulaevo
# Processing Record 31 of Set 6 | kiruna
# Processing Record 32 of Set 6 | carnarvon
# Processing Record 33 of Set 6 | bukama
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | lata
# Processing Record 36 of Set 6 | laguna
# Processing Record 37 of Set 6 | kamenka
# Processing Record 38 of Set 6 | thinadhoo
# Processing Record 39 of Set 6 | suntar
# Processing Record 40 of Set 6 | aksu
# Processing Record 41 of Set 6 | pauini
# Processing Record 42 of Set 6 | luderitz
# Processing Record 43 of Set 6 | antofagasta
# Processing Record 44 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 6 | wladyslawowo
# Processing Record 46 of Set 6 | berea
# Processing Record 47 of Set 6 | yatou
# Processing Record 48 of Set 6 | nioro
# Processing Record 49 of Set 6 | impfondo
# Processing Record 50 of Set 6 | sabzevar
# Processing Record 1 of Set 7 | zaysan
# Processing Record 2 of Set 7 | kulu
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | henties bay
# Processing Record 5 of Set 7 | maragogi
# Processing Record 6 of Set 7 | honiara
# Processing Record 7 of Set 7 | jhajjar
# Processing Record 8 of Set 7 | kitimat
# Processing Record 9 of Set 7 | adrar
# Processing Record 10 of Set 7 | chegutu
# Processing Record 11 of Set 7 | brus laguna
# Processing Record 12 of Set 7 | jiuquan
# Processing Record 13 of Set 7 | rio gallegos
# Processing Record 14 of Set 7 | kichera
# Processing Record 15 of Set 7 | sayyan
# Processing Record 16 of Set 7 | brae
# Processing Record 17 of Set 7 | yulara
# Processing Record 18 of Set 7 | chipinge
# Processing Record 19 of Set 7 | hvide sande
# Processing Record 20 of Set 7 | biysk
# Processing Record 21 of Set 7 | raga
# Processing Record 22 of Set 7 | petaling jaya
# Processing Record 23 of Set 7 | kampot
# Processing Record 24 of Set 7 | makakilo city
# Processing Record 25 of Set 7 | cidreira
# Processing Record 26 of Set 7 | villazon
# Processing Record 27 of Set 7 | anahuac
# Processing Record 28 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 7 | walvis bay
# Processing Record 32 of Set 7 | palu
# Processing Record 33 of Set 7 | wagar
# Processing Record 34 of Set 7 | moree
# Processing Record 35 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 7 | alofi
# Processing Record 37 of Set 7 | mount isa
# Processing Record 38 of Set 7 | meulaboh
# Processing Record 39 of Set 7 | canutama
# Processing Record 40 of Set 7 | souflion
# City not found. Skipping...
# Processing Record 41 of Set 7 | galesburg
# Processing Record 42 of Set 7 | ermelo
# Processing Record 43 of Set 7 | miles city
# Processing Record 44 of Set 7 | addi ugri
# City not found. Skipping...
# Processing Record 45 of Set 7 | tucuma
# Processing Record 46 of Set 7 | narsaq
# Processing Record 47 of Set 7 | visnes
# Processing Record 48 of Set 7 | sibi
# Processing Record 49 of Set 7 | kuytun
# Processing Record 50 of Set 7 | hami
# Processing Record 1 of Set 8 | jalingo
# Processing Record 2 of Set 8 | moro
# Processing Record 3 of Set 8 | guerrero negro
# Processing Record 4 of Set 8 | alindao
# Processing Record 5 of Set 8 | sao joao da barra
# Processing Record 6 of Set 8 | toamasina
# Processing Record 7 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 8 | tiksi
# Processing Record 9 of Set 8 | banamba
# Processing Record 10 of Set 8 | wasilla
# Processing Record 11 of Set 8 | sharjah
# Processing Record 12 of Set 8 | ballina
# Processing Record 13 of Set 8 | kingman
# Processing Record 14 of Set 8 | tecoanapa
# Processing Record 15 of Set 8 | alice springs
# Processing Record 16 of Set 8 | sistranda
# Processing Record 17 of Set 8 | zhanakorgan
# Processing Record 18 of Set 8 | copiapo
# Processing Record 19 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 20 of Set 8 | esperance
# Processing Record 21 of Set 8 | komsomolskiy
# Processing Record 22 of Set 8 | arman
# Processing Record 23 of Set 8 | san jose de guanipa
# Processing Record 24 of Set 8 | llandrindod wells
# Processing Record 25 of Set 8 | ponta delgada
# Processing Record 26 of Set 8 | san ramon
# Processing Record 27 of Set 8 | ulaanbaatar
# Processing Record 28 of Set 8 | yecla
# Processing Record 29 of Set 8 | havoysund
# Processing Record 30 of Set 8 | port-gentil
# Processing Record 31 of Set 8 | praia da vitoria
# Processing Record 32 of Set 8 | bonavista
# Processing Record 33 of Set 8 | banjar
# Processing Record 34 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 8 | nouadhibou
# Processing Record 36 of Set 8 | tchollire
# Processing Record 37 of Set 8 | hofn
# Processing Record 38 of Set 8 | bilma
# Processing Record 39 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 8 | vila velha
# Processing Record 41 of Set 8 | caravelas
# Processing Record 42 of Set 8 | avera
# Processing Record 43 of Set 8 | batagay
# Processing Record 44 of Set 8 | forio
# Processing Record 45 of Set 8 | guspini
# Processing Record 46 of Set 8 | tutoia
# Processing Record 47 of Set 8 | teguise
# Processing Record 48 of Set 8 | loubomo
# Processing Record 49 of Set 8 | genhe
# Processing Record 50 of Set 8 | san patricio
# Processing Record 1 of Set 9 | waingapu
# Processing Record 2 of Set 9 | moose factory
# Processing Record 3 of Set 9 | taltal
# Processing Record 4 of Set 9 | mancora
# Processing Record 5 of Set 9 | vastervik
# City not found. Skipping...
# Processing Record 6 of Set 9 | madras
# Processing Record 7 of Set 9 | woodstock
# Processing Record 8 of Set 9 | wuxue
# Processing Record 9 of Set 9 | new richmond
# Processing Record 10 of Set 9 | aden
# Processing Record 11 of Set 9 | chiredzi
# Processing Record 12 of Set 9 | zhangye
# Processing Record 13 of Set 9 | poanas
# Processing Record 14 of Set 9 | grand gaube
# Processing Record 15 of Set 9 | hobyo
# Processing Record 16 of Set 9 | sorland
# Processing Record 17 of Set 9 | aitape
# Processing Record 18 of Set 9 | concordia
# Processing Record 19 of Set 9 | broome
# Processing Record 20 of Set 9 | dawei
# Processing Record 21 of Set 9 | sao borja
# Processing Record 22 of Set 9 | teguldet
# Processing Record 23 of Set 9 | shevchenko
# Processing Record 24 of Set 9 | eenhana
# Processing Record 25 of Set 9 | merauke
# Processing Record 26 of Set 9 | sorong
# Processing Record 27 of Set 9 | nakhon phanom
# Processing Record 28 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 9 | rosario
# Processing Record 30 of Set 9 | makung
# City not found. Skipping...
# Processing Record 31 of Set 9 | pitkyaranta
# Processing Record 32 of Set 9 | kysyl-syr
# Processing Record 33 of Set 9 | vao
# Processing Record 34 of Set 9 | shelbyville
# Processing Record 35 of Set 9 | danilovka
# Processing Record 36 of Set 9 | kuvandyk
# Processing Record 37 of Set 9 | north bend
# Processing Record 38 of Set 9 | baillif
# Processing Record 39 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 9 | portland
# Processing Record 41 of Set 9 | victoria
# Processing Record 42 of Set 9 | ormoz
# Processing Record 43 of Set 9 | atka
# City not found. Skipping...
# Processing Record 44 of Set 9 | stephenville
# Processing Record 45 of Set 9 | plettenberg bay
# Processing Record 46 of Set 9 | manzhouli
# Processing Record 47 of Set 9 | tevaitoa
# Processing Record 48 of Set 9 | synya
# Processing Record 49 of Set 9 | yar-sale
# Processing Record 50 of Set 9 | kieta
# Processing Record 1 of Set 10 | lake charles
# Processing Record 2 of Set 10 | durham
# Processing Record 3 of Set 10 | haines junction
# Processing Record 4 of Set 10 | pakxan
# Processing Record 5 of Set 10 | puerto princesa
# Processing Record 6 of Set 10 | inuvik
# Processing Record 7 of Set 10 | salinopolis
# Processing Record 8 of Set 10 | bolivar
# Processing Record 9 of Set 10 | north branch
# Processing Record 10 of Set 10 | chino valley
# Processing Record 11 of Set 10 | krasnoselkup
# Processing Record 12 of Set 10 | northam
# Processing Record 13 of Set 10 | saint-joseph
# Processing Record 14 of Set 10 | paracatu
# Processing Record 15 of Set 10 | bandarbeyla
# Processing Record 16 of Set 10 | cedartown
# Processing Record 17 of Set 10 | coihaique
# Processing Record 18 of Set 10 | axim
# Processing Record 19 of Set 10 | ilulissat
# Processing Record 20 of Set 10 | vardo
# Processing Record 21 of Set 10 | kurdzhinovo
# Processing Record 22 of Set 10 | karamken
# City not found. Skipping...
# Processing Record 23 of Set 10 | tomatlan
# Processing Record 24 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 10 | dunmore town
# Processing Record 26 of Set 10 | mbini
# Processing Record 27 of Set 10 | ortona
# Processing Record 28 of Set 10 | mosetse
# Processing Record 29 of Set 10 | madimba
# Processing Record 30 of Set 10 | koslan
# Processing Record 31 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 10 | muros
# Processing Record 33 of Set 10 | nishihara
# Processing Record 34 of Set 10 | iqaluit
# Processing Record 35 of Set 10 | yuci
# Processing Record 36 of Set 10 | iracoubo
# Processing Record 37 of Set 10 | prado
# Processing Record 38 of Set 10 | malavalli
# Processing Record 39 of Set 10 | goure
# Processing Record 40 of Set 10 | linqing
# Processing Record 41 of Set 10 | road town
# Processing Record 42 of Set 10 | razole
# Processing Record 43 of Set 10 | mamakan
# Processing Record 44 of Set 10 | puerto cortes
# City not found. Skipping...
# Processing Record 45 of Set 10 | beloha
# Processing Record 46 of Set 10 | belaya gora
# Processing Record 47 of Set 10 | lulea
# Processing Record 48 of Set 10 | mandurah
# Processing Record 49 of Set 10 | ahipara
# Processing Record 50 of Set 10 | palmer
# Processing Record 1 of Set 11 | tshikapa
# Processing Record 2 of Set 11 | ostrovnoy
# Processing Record 3 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 4 of Set 11 | rudnichnyy
# Processing Record 5 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 6 of Set 11 | maxixe
# Processing Record 7 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 8 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 11 | muravlenko
# Processing Record 10 of Set 11 | vila do maio
# Processing Record 11 of Set 11 | marrakesh
# Processing Record 12 of Set 11 | fairbanks
# Processing Record 13 of Set 11 | qasigiannguit
# Processing Record 14 of Set 11 | lufkin
# Processing Record 15 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 11 | bhadrak
# Processing Record 17 of Set 11 | mujiayingzi
# Processing Record 18 of Set 11 | beringovskiy
# Processing Record 19 of Set 11 | brownsville
# Processing Record 20 of Set 11 | la vega
# Processing Record 21 of Set 11 | pangai
# Processing Record 22 of Set 11 | nizhniy baskunchak
# Processing Record 23 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 11 | castanos
# Processing Record 25 of Set 11 | ambagarh chauki
# Processing Record 26 of Set 11 | belmonte
# Processing Record 27 of Set 11 | valley city
# Processing Record 28 of Set 11 | ha tinh
# Processing Record 29 of Set 11 | ondo
# Processing Record 30 of Set 11 | santiago del estero
# Processing Record 31 of Set 11 | saurimo
# Processing Record 32 of Set 11 | hovsan
# Processing Record 33 of Set 11 | veraval
# Processing Record 34 of Set 11 | moerai
# Processing Record 35 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 36 of Set 11 | kulhudhuffushi
# Processing Record 37 of Set 11 | santa cruz de la palma
# Processing Record 38 of Set 11 | kizilskoye
# Processing Record 39 of Set 11 | lipari
# Processing Record 40 of Set 11 | barcelos
# Processing Record 41 of Set 11 | zyryanka
# Processing Record 42 of Set 11 | sanlucar la mayor
# Processing Record 43 of Set 11 | ascension
# Processing Record 44 of Set 11 | luwuk
# Processing Record 45 of Set 11 | booue
# Processing Record 46 of Set 11 | mirnyy
# Processing Record 47 of Set 11 | roanoke rapids
# Processing Record 48 of Set 11 | quatre cocos
# Processing Record 49 of Set 11 | maldonado
# Processing Record 50 of Set 11 | baleshwar
# Processing Record 1 of Set 12 | pithora
# Processing Record 2 of Set 12 | qafsah
# City not found. Skipping...
# Processing Record 3 of Set 12 | kudahuvadhoo
# Processing Record 4 of Set 12 | agadez
# Processing Record 5 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 12 | maralal
# Processing Record 7 of Set 12 | gondanglegi
# Processing Record 8 of Set 12 | mayfield
# Processing Record 9 of Set 12 | la rioja
# Processing Record 10 of Set 12 | vangaindrano
# Processing Record 11 of Set 12 | buala
# Processing Record 12 of Set 12 | general roca
# Processing Record 13 of Set 12 | dunedin
# Processing Record 14 of Set 12 | la asuncion
# Processing Record 15 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 12 | lahijan
# Processing Record 17 of Set 12 | iberia
# Processing Record 18 of Set 12 | dunda
# Processing Record 19 of Set 12 | dakar
# Processing Record 20 of Set 12 | venice
# Processing Record 21 of Set 12 | clarence town
# Processing Record 22 of Set 12 | muncar
# Processing Record 23 of Set 12 | pozzallo
# Processing Record 24 of Set 12 | pitimbu
# Processing Record 25 of Set 12 | vestmannaeyjar
# Processing Record 26 of Set 12 | kavaratti
# Processing Record 27 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 28 of Set 12 | were ilu
# Processing Record 29 of Set 12 | ewo
# Processing Record 30 of Set 12 | atar
# Processing Record 31 of Set 12 | ngong
# Processing Record 32 of Set 12 | khed
# Processing Record 33 of Set 12 | sibolga
# Processing Record 34 of Set 12 | huarmey
# Processing Record 35 of Set 12 | paamiut
# Processing Record 36 of Set 12 | monrovia
# Processing Record 37 of Set 12 | beboto
# Processing Record 38 of Set 12 | murgab
# Processing Record 39 of Set 12 | kikwit
# Processing Record 40 of Set 12 | macusani
# Processing Record 41 of Set 12 | rtishchevo
# Processing Record 42 of Set 12 | campos novos
# Processing Record 43 of Set 12 | green river
# Processing Record 44 of Set 12 | takab
# Processing Record 45 of Set 12 | petlad
# Processing Record 46 of Set 12 | jequie
# Processing Record 47 of Set 12 | karaton
# Processing Record 48 of Set 12 | pathein
# Processing Record 49 of Set 12 | ust-omchug
# Processing Record 50 of Set 12 | chumikan
# Processing Record 1 of Set 13 | goderich
# Processing Record 2 of Set 13 | usinsk
# Processing Record 3 of Set 13 | bata
# Processing Record 4 of Set 13 | safaga
# Processing Record 5 of Set 13 | san andres
# Processing Record 6 of Set 13 | trinidad
# Processing Record 7 of Set 13 | marapanim
# Processing Record 8 of Set 13 | carbonia
# Processing Record 9 of Set 13 | tuatapere
# Processing Record 10 of Set 13 | denpasar
# Processing Record 11 of Set 13 | jaciara
# Processing Record 12 of Set 13 | cayenne
# Processing Record 13 of Set 13 | mackay
# Processing Record 14 of Set 13 | riyadh
# Processing Record 15 of Set 13 | sept-iles
# Processing Record 16 of Set 13 | wajir
# Processing Record 17 of Set 13 | murud
# Processing Record 18 of Set 13 | angoche
# Processing Record 19 of Set 13 | otrado-kubanskoye
# Processing Record 20 of Set 13 | mtwara
# Processing Record 21 of Set 13 | havre-saint-pierre
# Processing Record 22 of Set 13 | milledgeville
# Processing Record 23 of Set 13 | ojinaga
# Processing Record 24 of Set 13 | miranorte
# City not found. Skipping...
# Processing Record 25 of Set 13 | gat
# Processing Record 26 of Set 13 | olinda
# Processing Record 27 of Set 13 | natal
# Processing Record 28 of Set 13 | araouane
# Processing Record 29 of Set 13 | cape canaveral

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hithadhoo      MV  -0.60   73.08     85.19        70          84
# 1         Moranbah      AU -22.00  148.05     57.18        43           1
# 2           Albany      US  42.60  -73.97     77.00        74          44
# 3      Fort Nelson      CA  58.81 -122.70     48.20       100          75
# 4         Katsuura      JP  35.13  140.30     72.00        88          75
# 5          Ushuaia      AR -54.80  -68.30     35.60        80          75
# 6        Jamestown      US  42.10  -79.24     73.99        73           1
# 7      Tuktoyaktuk      CA  69.45 -133.04     39.20       100          75
# 8         Necochea      AR -38.55  -58.74     42.01        72           0
# 9  Barra Do Garcas      BR -15.89  -52.26     82.40        45          99
#
#    Wind Speed          Current Description  Rain (inches)  Snow (inches)
# 0        6.87                broken clouds            0.0              0
# 1        7.29                    clear sky            0.0              0
# 2        3.00             scattered clouds            0.0              0
# 3        6.93                          fog            0.0              0
# 4       10.29  light intensity shower rain            0.0              0
# 5       18.34                  shower rain            0.0              0
# 6        6.02                    clear sky            0.0              0
# 7        4.70                         mist            0.0              0
# 8        7.00                    clear sky            0.0              0
# 9        4.54              overcast clouds            0.0              0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/weatherdatabase.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
