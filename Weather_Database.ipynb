# %%
# Import the dependencies.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
import timeit
import random

# Import the API key.
from config import g_key

# %%
gmaps.configure(api_key=g_key)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 623

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e141afc1224931002e974913d4c84ba9

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# List of city data
city_data = []# Print to logger
# print("Beginning Data Retrieval     ")
# print("-----------------------------")# Create counters
record_count = 1
set_count = 1# Loop through all the cities in our list
for i, city in enumerate(cities):    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")    # Add 1 to the record count
    record_count += 1    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        pass        
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        pass           
        # Append the City information into city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches})
    # If an error is experienced, skip the city    
    except:
        print("City not found. Skipping...")
        pass

    
# print("-----------------------------")
# print("Data Retrieval Complete      ")
#print("-----------------------------")
# Convert the array of dictionaries to a Pandas DataFrame.
# Out:
# Processing Record 1 of Set 1 | palimbang
# Processing Record 2 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 1 | vao
# Processing Record 4 of Set 1 | tupancireta
# Processing Record 5 of Set 1 | huarmey
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | pindi gheb
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | kahului
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | lima
# Processing Record 13 of Set 1 | pochutla
# Processing Record 14 of Set 1 | yellowknife
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | makakilo city
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | lagoa
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 1 | georgetown
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Palimbang      PH   6.21  124.19     79.74        78          97
# 1           Vao      NC -22.67  167.48     69.80        76          73
# 2   Tupancireta      BR -29.08  -53.84     55.38        97         100
# 3       Huarmey      PE -10.07  -78.15     63.07        76           1
# 4     Mahebourg      MU -20.41   57.70     69.80        73          40
# 5   Port Alfred      ZA -33.59   26.89     52.00        72          37
# 6    Pindi Gheb      PK  33.24   72.27     71.60        88          40
# 7        Avarua      CK -21.21 -159.78     75.20        83          96
# 8       Kahului      US  20.89 -156.47     89.60        43          40
# 9  Punta Arenas      CL -53.15  -70.92     33.80        74          40
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        4.09          light rain           0.22              0
# ...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/citieschallenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
